# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data=pd.read_csv('/content/WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
data.shape
# Out:
# (7043, 21)

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
a=LabelEncoder()
x=['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
       'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn']
for i in x:
  data[i]=a.fit_transform(data[i])
data
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0           5375       0              0        1           0       1
# 1           3962       1              0        0           0      34
# 2           2564       1              0        0           0       2
# 3           5535       1              0        0           0      45
# 4           6511       0              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038        4853       1              0        1           1      24
# 7039        1525       0              0        1           1      72
# 7040        3367       0              0        1           1      11
# 7041        5934       1              1        1           0       4
# 7042        2226       1              0        0           0      66
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
 import seaborn as sns
corr=data.corr()
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
data.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
x=data.drop(['Churn'],axis=1)
x
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0           5375       0              0        1           0       1
# 1           3962       1              0        0           0      34
# 2           2564       1              0        0           0       2
# 3           5535       1              0        0           0      45
# 4           6511       0              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038        4853       1              0        1           1      24
# 7039        1525       0              0        1           1      72
# 7040        3367       0              0        1           1      11
# 7041        5934       1              1        1           0       4
# 7042        2226       1              0        0           0      66
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  \
# 0                0              1                0               0
# ...

# %%
y=data['Churn']
y
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    1
# 7042    0
# Name: Churn, Length: 7043, dtype: int64

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=.2)

# %%
xtrain.shape,xtest.shape,ytrain.shape,ytest.shape
# Out:
# ((5634, 20), (1409, 20), (5634,), (1409,))

# %%
from keras.models import Sequential
from keras.layers import Dense
model=Sequential()
model.add(Dense(128,activation='relu',input_dim=20,kernel_initializer='uniform'))
model.add(Dense(64,activation='relu',kernel_initializer='uniform'))
model.add(Dense(32,activation='relu',kernel_initializer='uniform'))
model.add(Dense(1,activation='sigmoid',kernel_initializer='uniform'))

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.fit(xtrain,ytrain,epochs=20,batch_size=10,verbose=1)
# Out:
# Epoch 1/20
# 564/564 [==============================] - 2s 2ms/step - loss: 4.1697 - accuracy: 0.7297
# Epoch 2/20
# 564/564 [==============================] - 1s 2ms/step - loss: 4.1697 - accuracy: 0.7297
# Epoch 3/20
# 564/564 [==============================] - 1s 2ms/step - loss: 4.1697 - accuracy: 0.7297
# Epoch 4/20
# 564/564 [==============================] - 1s 2ms/step - loss: 4.1697 - accuracy: 0.7297
# Epoch 5/20
# 564/564 [==============================] - 1s 2ms/step - loss: 4.1697 - accuracy: 0.7297
# Epoch 6/20
# 564/564 [==============================] - 1s 3ms/step - loss: 4.1697 - accuracy: 0.7297
# Epoch 7/20
# 564/564 [==============================] - 2s 3ms/step - loss: 4.1697 - accuracy: 0.7297
# Epoch 8/20
# 564/564 [==============================] - 2s 3ms/step - loss: 4.1697 - accuracy: 0.7297
# Epoch 9/20
# 564/564 [==============================] - 1s 2ms/step - loss: 4.1697 - accuracy: 0.7297
# Epoch 10/20
# ...

# %%
score=model.evaluate(xtest,ytest)
# Out:
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4184 - accuracy: 0.7991

# %%
model.metrics_names
# Out:
# ['loss', 'accuracy']

# %%
print(score)
# Out:
# [0.4183593988418579, 0.7991483211517334]

# %%
 v  v=np.array([[5375,0,0,1,0,1,0,1,0,0,2,0,0,0,0,0,1,2,142,2505]])
out=model.predict(v)
print(out)
# Out:
# 1/1 [==============================] - 0s 105ms/step
# [[0.3257442]]
